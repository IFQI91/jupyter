# %% [markdown]
# # Ejemplo 1 Computo aplicado

# %% [markdown]
# <h1>Ejemplo html</h1>

# %% [markdown]
# ## Mi primer ejercicio en R

# %%
x=c(1,2,3)
y=c(2,3,4)
plot(x,y,col="red",pch=17)

abline(lm(y~x),col="blue")
abline(h=3.0,v=2.0)
plot(x,y,col="red",pch=17)
# Out:
# plot without title
# plot without title

# %%
#install.packages('agricolae')

# %%
library(agricolae)

# %%
data()

# %%
iris <- iris
class(iris)
# Out:
# [1] "data.frame"

# %%
names(iris)
# Out:
# [1] "Sepal.Length" "Sepal.Width"  "Petal.Length" "Petal.Width"  "Species"

# %%
plot(iris)
# Out:
# plot without title

# %%
cor(iris[,-5])
# Out:
#              Sepal.Length Sepal.Width Petal.Length Petal.Width
# Sepal.Length  1.0000000   -0.1175698   0.8717538    0.8179411
# Sepal.Width  -0.1175698    1.0000000  -0.4284401   -0.3661259
# Petal.Length  0.8717538   -0.4284401   1.0000000    0.9628654
# Petal.Width   0.8179411   -0.3661259   0.9628654    1.0000000

# %%
boxplot(iris$Sepal.Length~iris$Species,
  main="Iris (Longitud de sepalo por especie)", xlab="Especie",ylab="Longitud de sepalo")
media <- tapply(iris$Sepal.Length,iris$Species,mean)
points(media, col="red",pch=16)
# Out:
# Plot with title “Iris (Longitud de sepalo por especie)”

# %%
media <- tapply(iris$Sepal.Length,iris$Species,mean)
media

# %%
iris

# %%
ls()

# %%
attach(iris)

# %%
ml <- lm(Sepal.Length~Sepal.Width, data=iris)
summary(ml)

# %%
shapiro.test(ml$residuals)

# %%
hist(ml$residuals)

# %%
pca=prcomp(iris[,-5],scale=T, center=T)
summary(pca)
biplot(pca)
plot(pca$x[,1],pca$x[,2], col=as.factor(iris$Species))
