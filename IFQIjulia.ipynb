# %%
exp(2)
# Out:
# 7.38905609893065

# %%
2^2
# Out:
# 4

# %%
println("¡Hola, mundo!")
# Out:
# ¡Hola, mundo!

# %%
x=[1, 2, 3,20];
y=[2, 3, 5,15];

plot(x,y)

# %%
using Plots
x = 1:10; y = rand(10); # These are the plotting data
plot(x, y)

# %%
#Instalar paquetes
#using Pkg
#Pkg.add("Plots")
